# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import os
import time
from skimage.transform import resize
import nibabel as nib

# %%
def window_image(image, window_center=60, window_width=120):
    img_min = window_center - window_width // 2
    img_max = window_center + window_width // 2
    window_image = image.copy()
    window_image[window_image < img_min] = img_min
    window_image[window_image > img_max] = img_max
    return window_image

# %%
input_path_adc = "/home/gustavogarzon/Videos/nifti/"
#input_path_ncct = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwi/"

output_path = "/data/gustavogarzon/backup/pytorch-CycleGAN-and-pix2pix/datasets/apis/test/"

#mylist = os.listdir(input_path_adc)
mylist = next(os.walk(input_path_adc))[2]
mylist.sort()

#t0 = time.time()

for fn in mylist:
    img = nib.load(os.path.join(input_path_adc, fn)).get_fdata()
    img = resize(img, (256,256))
    img = window_image(img)
    print(img.shape)
    black = np.zeros((256,256))
    
    for s in range(img.shape[-1]):
        newimg = np.zeros((img.shape[0],img.shape[0]*2))
        # print(newimg.shape)
        newimg[:,:img.shape[0]] = img[:,:,s]
        newimg[:,img.shape[0]:] = black
        # #print(myimg1.shape)
        # #print(myimg2.shape)
        # pts = f.split("_")
        output_file = fn[:7]+"_"+str(s)+".png"
        # print(output_file+"\n")
        plt.imsave(output_path+output_file, newimg, cmap="gray")
        #plt.imshow(newimg, cmap="gray")
        #plt.show()
        #break
    break

#print("Elapsed:", time.time()-t0)
# Out:
# ACV-294_SER__Head_7.0_Axial.1.nii.gz
# A
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/nibabel/loadsave.py:100, in load(filename, **kwargs)
#      99 try:
# --> 100     stat_result = os.stat(filename)
#     101 except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/gustavogarzon/Videos/nifti/A'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[29], line 14
#      12 for fn in mylist[0]:
#      13     print(fn)
# ---> 14     img = nib.load(os.path.join(input_path_adc, fn)).get_fdata()
#      15     img = resize(img, (256,256))
#      16     img = window_image(img)
#
# File /opt/conda/lib/python3.10/site-packages/nibabel/loadsave.py:102, in load(filename, **kwargs)
# ...

# %%
#imsave("xxx.jpg", newimg, cmap="gray")
myimg = mpimg.imread("xxx.jpg")
myimg.shape

# %% [markdown]
# <div style="height:200px;"></div>

# %%
input_path_adc = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc/"
input_path_ncct = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct/"
input_path_mask = "/data/Datasets/stroke/ggarzon/foscal_jpg/mask/"

#output_path = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc2ncct/"
output_path = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc2ncct/testmask2/"

mylist = os.listdir(input_path_adc)
#mylist = os.listdir(input_path_ncct)
mylist.sort()

t0 = time.time()

for f in mylist:
    #f2 = f.replace("adc","ncct") #train_000_adc_10.jpg
    pts = f.split("_")  #train_000_r1_mask_10.jpg
    f2 = pts[0]+"_"+pts[1]+"_r1_mask_"+pts[3]
    print(f, f2)
    myimg1 = mpimg.imread(input_path_adc+f)
    myimg2 = mpimg.imread(input_path_mask+f2)
    #myimg1 = mpimg.imread(input_path_ncct+f)
    #myimg2 = mpimg.imread(input_path_adc+f2)
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    print(newimg.shape)
    newimg[:,:myimg1.shape[0]] = myimg1[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg2[:,:,0]
    #print(myimg1.shape)
    #print(myimg2.shape)
    pts = f.split("_")
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    print(output_file+"\n")
    plt.imsave(output_path+output_file, newimg, cmap="gray")
    #plt.imshow(newimg, cmap="gray")
    #plt.show()
    #break

print("Elapsed:", time.time()-t0)

# %% [markdown]
# <div style="height:200px;"></div>

# %%
input_path_adc = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc/"
input_path_ncct = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct/"
input_path_mask = "/data/Datasets/stroke/ggarzon/foscal_jpg/mask/"

#output_path = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc2ncct/"
output_path = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct2adc/"

#mylist = os.listdir(input_path_adc)
mylist = os.listdir(input_path_ncct)
mylist.sort()

t0 = time.time()

for f in mylist:
    #f2 = f.replace("adc","ncct")
    f2 = f.replace("ncct","adc")
    print(f, f2)
    #myimg1 = mpimg.imread(input_path_adc+f)
    #myimg2 = mpimg.imread(input_path_ncct+f2)
    myimg1 = mpimg.imread(input_path_ncct+f)
    myimg2 = mpimg.imread(input_path_adc+f2)
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    print(newimg.shape)
    newimg[:,:myimg1.shape[0]] = myimg1[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg2[:,:,0]
    #print(myimg1.shape)
    #print(myimg2.shape)
    pts = f.split("_")
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    print(output_file+"\n")
    plt.imsave(output_path+output_file, newimg, cmap="gray")
    #plt.imshow(newimg, cmap="gray")
    #plt.show()
    break

print("Elapsed:", time.time()-t0)

# %% [markdown]
# <div style="height:200px;"></div>

# %%
input_path_dwi = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwiss/"
input_path_ncct = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncctss/"
#input_path_mask = "/data/Datasets/stroke/ggarzon/foscal_jpg/mask/"

output_path = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct2dwi/"
output_path2 = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwi2ncct/"

#mylist = os.listdir(input_path_adc)
mylist = os.listdir(input_path_ncct)
mylist.remove("test")
mylist.sort()

t0 = time.time()

for f in mylist:
    #f2 = f.replace("adc","ncct")
    f2 = f.replace("ncct","dwiss")
    print(f, f2)
    #myimg1 = mpimg.imread(input_path_adc+f)
    #myimg2 = mpimg.imread(input_path_ncct+f2)
    myimg1 = mpimg.imread(input_path_ncct+f)
    myimg2 = mpimg.imread(input_path_dwi+f2)
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    print(newimg.shape)
    newimg[:,:myimg1.shape[0]] = myimg1[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg2[:,:,0]
    #print(myimg1.shape)
    #print(myimg2.shape)
    pts = f.split("_")
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    print(output_file+"\n")
    plt.imsave(output_path2+output_file, newimg, cmap="gray")
    #plt.imshow(newimg, cmap="gray")
    #plt.show()
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    newimg[:,:myimg1.shape[0]] = myimg2[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg1[:,:,0]
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    plt.imsave(output_path2+output_file, newimg, cmap="gray")
    #break

print("Elapsed:", time.time()-t0)

# %%
input_path_dwi = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwiss/test/"
input_path_ncct = "/data/Datasets/stroke/ggarzon/foscal_jpg/adcss/"
#input_path_mask = "/data/Datasets/stroke/ggarzon/foscal_jpg/mask/"

output_path = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc2dwi/"
output_path2 = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwi2adc/"

mylist = os.listdir(input_path_dwi)
#mylist.remove("test")
mylist.sort()

t0 = time.time()

for f in mylist:
    f2 = f.replace("dwiss","adc")
    print(f, f2)
    #myimg1 = mpimg.imread(input_path_adc+f)
    #myimg2 = mpimg.imread(input_path_ncct+f2)
    myimg1 = mpimg.imread(input_path_ncct+f2)
    myimg2 = mpimg.imread(input_path_dwi+f)
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    print(newimg.shape)
    newimg[:,:myimg1.shape[0]] = myimg1[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg2[:,:,0]
    #print(myimg1.shape)
    #print(myimg2.shape)
    pts = f.split("_")
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    print(output_file+"\n")
    plt.imsave(output_path+output_file, newimg, cmap="gray")
    #plt.imshow(newimg, cmap="gray")
    #plt.show()
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    newimg[:,:myimg1.shape[0]] = myimg2[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg1[:,:,0]
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    plt.imsave(output_path2+output_file, newimg, cmap="gray")
    #break

print("Elapsed:", time.time()-t0)

# %% [raw]
# input_path_adc = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwiss/"
# aaa = os.listdir(input_path_adc)
# aaa.sort()
#
# for f in aaa:
#     print(f)

# %% [raw]
# input_path_ncct = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct/"
# aaa = os.listdir(input_path_ncct)
# aaa.sort()
#
# for f in aaa:
#     print(f)

# %%
mypath = "data/custom-adc2dwi/trainA/"
mylist = os.listdir(mypath)
mylist.sort()
for i in mylist:
    myimg = mpimg.imread(mypath+i)
    print(i, myimg.shape)
#     if "train_049" in i:
#         print(i)
#         myimg = mpimg.imread(mypath+i)
#         myimg = sk.resize(myimg[:,:,0], (256,256))
#         plt.imsave(mypath+i, myimg, cmap="gray")
#         print("\t",myimg.shape)
# Out:
# train_000_adc_10.png (256, 256, 4)
# train_000_adc_11.png (256, 256, 4)
# train_000_adc_12.png (256, 256, 4)
# train_000_adc_13.png (256, 256, 4)
# train_000_adc_14.png (256, 256, 4)
# train_000_adc_15.png (256, 256, 4)
# train_000_adc_16.png (256, 256, 4)
# train_000_adc_17.png (256, 256, 4)
# train_000_adc_18.png (256, 256, 4)
# train_000_adc_19.png (256, 256, 4)
# train_000_adc_20.png (256, 256, 4)
# train_000_adc_21.png (256, 256, 4)
# train_000_adc_22.png (256, 256, 4)
# train_000_adc_23.png (256, 256, 4)
# train_001_adc_10.png (256, 256, 4)
# train_001_adc_11.png (256, 256, 4)
# train_001_adc_12.png (256, 256, 4)
# train_001_adc_13.png (256, 256, 4)
# train_001_adc_14.png (256, 256, 4)
# train_001_adc_15.png (256, 256, 4)
# train_001_adc_16.png (256, 256, 4)
# train_001_adc_17.png (256, 256, 4)
# train_001_adc_18.png (256, 256, 4)
# train_001_adc_19.png (256, 256, 4)
# train_001_adc_20.png (256, 256, 4)
# train_001_adc_21.png (256, 256, 4)
# train_001_adc_9.png (256, 256, 4)
# ...

# %%
mypath = "data/custom-ncct2dwi/testA/"
mylist = os.listdir(mypath)
mylist.sort()
for i in mylist:
    #myimg = mpimg.imread(mypath+i)
    #print(i, myimg.shape)
    if "train_049" in i:
        print(i)
        myimg = mpimg.imread(mypath+i)
        myimg = sk.resize(myimg[:,:,0], (256,256))
        plt.imsave(mypath+i, myimg, cmap="gray")
        print("\t",myimg.shape)
# Out:
# train_049_ncct_10.png
# 	 (256, 256)
# train_049_ncct_11.png
# 	 (256, 256)
# train_049_ncct_12.png
# 	 (256, 256)
# train_049_ncct_13.png
# 	 (256, 256)
# train_049_ncct_14.png
# 	 (256, 256)
# train_049_ncct_15.png
# 	 (256, 256)
# train_049_ncct_16.png
# 	 (256, 256)
# train_049_ncct_17.png
# 	 (256, 256)
# train_049_ncct_18.png
# 	 (256, 256)
# train_049_ncct_19.png
# 	 (256, 256)
# train_049_ncct_20.png
# 	 (256, 256)
# train_049_ncct_21.png
# 	 (256, 256)
# train_049_ncct_9.png
# 	 (256, 256)

# %%
mypath = "data/custom-ncct2dwi/testA/"
myimg = mpimg.imread(mypath+"train_059_ncct_10.png")
print(myimg.shape)
# Out:
# (256, 256, 4)

# %% [markdown]
# ## Non-skull stripped

# %%
input_path_adc = "/data/Datasets/stroke/ggarzon/foscal_jpg_noss/adc/test/"
input_path_ncct = "/data/Datasets/stroke/ggarzon/foscal_jpg_noss/ncct/test/"
input_path_dwi = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwi/test/"
input_path_mask = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncctmask/test/"

output_path = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct2adc-noss/"
output_path2 = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc2ncct-noss/"
output_path3 = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct2adc-noss/mask/"

output_path4 = "/data/Datasets/stroke/ggarzon/foscal_jpg/adc2dwi-noss/"
output_path5 = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwi2adc-noss/"

output_path6 = "/data/Datasets/stroke/ggarzon/foscal_jpg/dwi2ncct-noss/"
output_path7 = "/data/Datasets/stroke/ggarzon/foscal_jpg/ncct2dwi-noss/"

input_path = input_path_ncct

# %%
mylist = os.listdir(input_path)
mylist.sort()
#mylist.remove("test")
t0 = time.time()

for f in mylist:
    f2 = f.replace("ncct","dwi")
    print(f, f2)
    myimg1 = mpimg.imread(input_path_dwi+f2)
    myimg2 = mpimg.imread(input_path_ncct+f)
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    print(newimg.shape)
    newimg[:,:myimg1.shape[0]] = myimg1[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg2[:,:,0]
    #print(myimg1.shape)
    #print(myimg2.shape)
    pts = f.split("_")
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    print(output_file+"\n")
    plt.imsave(output_path6+output_file, newimg, cmap="gray")
    #plt.imshow(newimg, cmap="gray")
    #plt.show()
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    newimg[:,:myimg1.shape[0]] = myimg2[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg1[:,:,0]
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    plt.imsave(output_path7+output_file, newimg, cmap="gray")
    
    #f3 = f.replace("adc","maskncct")
    #myimg3 = mpimg.imread(input_path_mask+f3)
    #newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    #newimg[:,:myimg1.shape[0]] = myimg2[:,:,0]
    #newimg[:,myimg1.shape[0]:] = myimg3[:,:,0]
    #output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    #plt.imsave(output_path3+output_file, newimg, cmap="gray")
    #break

print("Elapsed:", time.time()-t0)
# Out:
# train_048_ncct_10.jpg train_048_dwi_10.jpg
# (256, 512)
# train_048_10.jpg
#
# train_048_ncct_11.jpg train_048_dwi_11.jpg
# (256, 512)
# train_048_11.jpg
#
# train_048_ncct_12.jpg train_048_dwi_12.jpg
# (256, 512)
# train_048_12.jpg
#
# train_048_ncct_13.jpg train_048_dwi_13.jpg
# (256, 512)
# train_048_13.jpg
#
# train_048_ncct_14.jpg train_048_dwi_14.jpg
# (256, 512)
# train_048_14.jpg
#
# train_048_ncct_15.jpg train_048_dwi_15.jpg
# (256, 512)
# train_048_15.jpg
#
# train_048_ncct_16.jpg train_048_dwi_16.jpg
# (256, 512)
# train_048_16.jpg
#
# train_048_ncct_17.jpg train_048_dwi_17.jpg
# (256, 512)
# train_048_17.jpg
#
# train_048_ncct_18.jpg train_048_dwi_18.jpg
# (256, 512)
# train_048_18.jpg
#
# train_048_ncct_19.jpg train_048_dwi_19.jpg
# (256, 512)
# train_048_19.jpg
#
# train_048_ncct_20.jpg train_048_dwi_20.jpg
# (256, 512)
# train_048_20.jpg
#
# train_048_ncct_21.jpg train_048_dwi_21.jpg
# (256, 512)
# train_048_21.jpg
#
# train_048_ncct_8.jpg train_048_dwi_8.jpg
# ...

# %%
mylist = os.listdir(input_path)
mylist.sort()
#mylist.remove("test")
t0 = time.time()

for f in mylist:
    f2 = f.replace("adc","ncct")
    print(f, f2)
    myimg1 = mpimg.imread(input_path_ncct+f2)
    myimg2 = mpimg.imread(input_path_adc+f)
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    print(newimg.shape)
    newimg[:,:myimg1.shape[0]] = myimg1[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg2[:,:,0]
    #print(myimg1.shape)
    #print(myimg2.shape)
    pts = f.split("_")
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    print(output_file+"\n")
    plt.imsave(output_path+output_file, newimg, cmap="gray")
    #plt.imshow(newimg, cmap="gray")
    #plt.show()
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    newimg[:,:myimg1.shape[0]] = myimg2[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg1[:,:,0]
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    plt.imsave(output_path2+output_file, newimg, cmap="gray")
    
    f3 = f.replace("adc","maskncct")
    myimg3 = mpimg.imread(input_path_mask+f3)
    newimg = np.zeros((myimg1.shape[0],myimg1.shape[0]*2))
    newimg[:,:myimg1.shape[0]] = myimg2[:,:,0]
    newimg[:,myimg1.shape[0]:] = myimg3[:,:,0]
    output_file = pts[0]+"_"+pts[1]+"_"+pts[3]
    plt.imsave(output_path3+output_file, newimg, cmap="gray")
    #break

print("Elapsed:", time.time()-t0)
