# %% [markdown]
# # Training
#
# -   `python train.py --dataroot ./datasets/facades --name facades_pix2pix --model pix2pix --direction BtoA`
#
# Change the `--dataroot` and `--name` to your own dataset's path and model's name. Use `--gpu_ids 0,1,..` to train on multiple GPUs and `--batch_size` to change the batch size. Add `--direction BtoA` if you want to train a model to transfrom from class B to A.

# %% [raw]
# --continue_train --epoch_count 165
# !python train.py --dataroot ./datasets/apis2/ --segroot ./datasets/apis2_mask --name test_liu_ncct2adc --model pix2pix --direction AatoB --display_id -1

# %%
# !python train.p

y --dataroot ./datasets/apis2/ --name test_liu_ncct2adc_y --model pix2pix --direction AtoB --display_id -1
# Out:
# Setting up [LPIPS] perceptual loss: trunk [vgg], v[0.1], spatial [off]
# Loading model from: /opt/conda/lib/python3.7/site-packages/lpips/weights/v0.1/vgg.pth
# ----------------- Options ---------------
#                batch_size: 1
#                     beta1: 0.5
#           checkpoints_dir: ./checkpoints
#            continue_train: False
#                 crop_size: 256
#                  dataroot: ./datasets/apis2/             	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#               display_env: main
#              display_freq: 400
#                display_id: -1                            	[default: 1]
#             display_ncols: 4
#              display_port: 8097
#            display_server: http://localhost
#           display_winsize: 256
#                     epoch: latest
#               epoch_count: 1
#                  gan_mode: vanilla
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: True                          	[default: None]
#                 lambda_L1: 100.0
#                 load_iter: 0                             	[default: 0]
#                 load_size: 286
#                        lr: 0.0002
#            lr_decay_iters: 50
#                 lr_policy: linear
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: cycle_gan]
#                  n_epochs: 100
#            n_epochs_decay: 100
#                n_layers_D: 3
#                      name: test_liu_ncct2adc_x           	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: False
#                   no_flip: False
#                   no_html: False
#                      norm: batch
#               num_threads: 4
#                 output_nc: 3
#                     phase: train
#                 pool_size: 0
#                preprocess: resize_and_crop
#                print_freq: 100
#              save_by_iter: False
#           save_epoch_freq: 5
#          save_latest_freq: 5000
#                   segroot: None
#            serial_batches: False
#                    suffix:
#          update_html_freq: 1000
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# The number of training images = 6755
# initialize network with normal
# initialize network with normal
# model [Pix2PixModel] was created
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.414 M
# [Network D] Total number of parameters : 1.080 M
# -----------------------------------------------
# create web directory ./checkpoints/test_liu_ncct2adc_x/web...
# /opt/conda/lib/python3.7/site-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# learning rate 0.0002000 -> 0.0002000
# (epoch: 1, iters: 100, time: 0.098, data: 0.279) G_GAN: 0.635 G_L1: 15.729 D_real: 0.633 D_fake: 0.760
# (epoch: 1, iters: 200, time: 0.102, data: 0.001) G_GAN: 0.645 G_L1: 4.571 D_real: 0.639 D_fake: 0.752
# (epoch: 1, iters: 300, time: 0.094, data: 0.001) G_GAN: 0.652 G_L1: 8.795 D_real: 0.625 D_fake: 0.742
# (epoch: 1, iters: 400, time: 0.175, data: 0.001) G_GAN: 0.659 G_L1: 5.475 D_real: 0.614 D_fake: 0.737
# (epoch: 1, iters: 500, time: 0.093, data: 0.001) G_GAN: 0.665 G_L1: 7.260 D_real: 0.619 D_fake: 0.731
# (epoch: 1, iters: 600, time: 0.098, data: 0.001) G_GAN: 0.677 G_L1: 5.724 D_real: 0.611 D_fake: 0.716
://github.com/junyanz/pytorch-CycleGAN-and-pix2pix:
# > Note that we specified --direction BtoA as Facades dataset's A to B direction is photos to labels.
#
# > If you would like to apply a pre-trained model to a collection of input images (rather than image pairs), please use --model test option. See ./scripts/test_single.sh for how to apply a model to Facade label maps (stored in the directory facades/testB).
#
# > See a list of currently available models at ./scripts/download_pix2pix_model.sh

# %%
# !ls checkpoints/

# %%
#!python test.py --dataroot datasets/apis2/ --direction AtoB --model pix2pix --name test_liu_ncct2adc_y --num_test 4267 --no_dropout
# !python test.py --dataroot datasets/apis/ --direction AtoB --model pix2pix --name apis_pix2pix_NCCT_ADC --num_test 29 --no_dropout
# Out:
# ----------------- Options ---------------
#              aspect_ratio: 1.0
#                batch_size: 1
#           checkpoints_dir: ./checkpoints
#                 crop_size: 256
#                  dataroot: datasets/apis/                	[default: None]
#              dataset_mode: aligned
#                 direction: AtoB
#           display_winsize: 256
#                     epoch: latest
#                      eval: False
#                   gpu_ids: 0
#                 init_gain: 0.02
#                 init_type: normal
#                  input_nc: 3
#                   isTrain: False                         	[default: None]
#                 load_iter: 0                             	[default: 0]
#                 load_size: 256
#          max_dataset_size: inf
#                     model: pix2pix                       	[default: test]
#                n_layers_D: 3
#                      name: apis_pix2pix_NCCT_ADC         	[default: experiment_name]
#                       ndf: 64
#                      netD: basic
#                      netG: unet_256
#                       ngf: 64
#                no_dropout: True                          	[default: False]
#                   no_flip: False
#                      norm: batch
#                  num_test: 29                            	[default: 50]
#               num_threads: 4
#                 output_nc: 3
#                     phase: test
#                preprocess: resize_and_crop
#               results_dir: ./results/
#                   segroot: None
#            serial_batches: False
#                    suffix:
#                 use_wandb: False
#                   verbose: False
#        wandb_project_name: CycleGAN-and-pix2pix
# ----------------- End -------------------
# dataset [AlignedDataset] was created
# initialize network with normal
# model [Pix2PixModel] was created
# loading the model from ./checkpoints/apis_pix2pix_NCCT_ADC/latest_net_G.pth
# ---------- Networks initialized -------------
# [Network G] Total number of parameters : 54.414 M
# -----------------------------------------------
# creating web directory ./results/apis_pix2pix_NCCT_ADC/test_latest
# processing (0000)-th image... ['datasets/apis/test/ACV-294_0.png']
# processing (0005)-th image... ['datasets/apis/test/ACV-294_13.png']
# processing (0010)-th image... ['datasets/apis/test/ACV-294_18.png']
# processing (0015)-th image... ['datasets/apis/test/ACV-294_22.png']
# processing (0020)-th image... ['datasets/apis/test/ACV-294_27.png']
# processing (0025)-th image... ['datasets/apis/test/ACV-294_6.png']
# processing (3290)-th image... ['datasets/apis2/test/test_029_26.png']
# processing (3295)-th image... ['datasets/apis2/test/test_029_31.png']
# processing (3300)-th image... ['datasets/apis2/test/test_029_36.png']
# processing (3305)-th image... ['datasets/apis2/test/test_029_41.png']
# processing (3310)-th image... ['datasets/apis2/test/test_029_46.png']
# processing (3315)-th image... ['datasets/apis2/test/test_029_51.png']
# processing (3320)-th image... ['datasets/apis2/test/test_029_56.png']
# processing (3325)-th image... ['datasets/apis2/test/test_029_61.png']
# processing (3330)-th image... ['datasets/apis2/test/test_029_66.png']
# processing (3335)-th image... ['datasets/apis2/test/test_029_71.png']
# processing (3340)-th image... ['datasets/apis2/test/test_029_76.png']
# processing (3345)-th image... ['datasets/apis2/test/test_029_81.png']
# processing (3350)-th image... ['datasets/apis2/test/test_029_86.png']
# processing (3355)-th image... ['datasets/apis2/test/test_029_91.png']
# processing (3360)-th image... ['datasets/apis2/test/test_029_96.png']
# processing (3365)-th image... ['datasets/apis2/test/test_030_101.png']
# processing (3370)-th image... ['datasets/apis2/test/test_030_106.png']
# processing (3375)-th image... ['datasets/apis2/test/test_030_111.png']
# processing (3380)-th image... ['datasets/apis2/test/test_030_116.png']
# processing (3385)-th image... ['datasets/apis2/test/test_030_121.png']
# processing (3390)-th image... ['datasets/apis2/test/test_030_126.png']
# processing (3395)-th image... ['datasets/apis2/test/test_030_131.png']
# processing (3400)-th image... ['datasets/apis2/test/test_030_136.png']
# processing (3405)-th image... ['datasets/apis2/test/test_030_24.png']
# processing (3410)-th image... ['datasets/apis2/test/test_030_29.png']
# processing (3415)-th image... ['datasets/apis2/test/test_030_34.png']
# processing (3420)-th image... ['datasets/apis2/test/test_030_39.png']
# processing (3425)-th image... ['datasets/apis2/test/test_030_44.png']
# processing (3430)-th image... ['datasets/apis2/test/test_030_49.png']
# processing (3435)-th image... ['datasets/apis2/test/test_030_54.png']
# processing (3440)-th image... ['datasets/apis2/test/test_030_59.png']
# processing (3445)-th image... ['datasets/apis2/test/test_030_64.png']
# processing (3450)-th image... ['datasets/apis2/test/test_030_69.png']
# processing (3455)-th image... ['datasets/apis2/test/test_030_74.png']
# processing (3460)-th image... ['datasets/apis2/test/test_030_79.png']
# processing (3465)-th image... ['datasets/apis2/test/test_030_84.png']
# processing (3470)-th image... ['datasets/apis2/test/test_030_89.png']
# processing (3475)-th image... ['datasets/apis2/test/test_030_94.png']
# processing (3480)-th image... ['datasets/apis2/test/test_030_99.png']
# processing (3485)-th image... ['datasets/apis2/test/test_031_104.png']
# processing (3490)-th image... ['datasets/apis2/test/test_031_109.png']
# processing (3495)-th image... ['datasets/apis2/test/test_031_114.png']
# processing (3500)-th image... ['datasets/apis2/test/test_031_119.png']
# processing (3505)-th image... ['datasets/apis2/test/test_031_124.png']
# processing (3510)-th image... ['datasets/apis2/test/test_031_129.png']
# processing (3515)-th image... ['datasets/apis2/test/test_031_134.png']
# processing (3520)-th image... ['datasets/apis2/test/test_031_139.png']
# processing (3525)-th image... ['datasets/apis2/test/test_031_144.png']
# processing (3530)-th image... ['datasets/apis2/test/test_031_31.png']
# processing (3535)-th image... ['datasets/apis2/test/test_031_36.png']
# processing (3540)-th image... ['datasets/apis2/test/test_031_41.png']
# processing (3545)-th image... ['datasets/apis2/test/test_031_46.png']
# processing (3550)-th image... ['datasets/apis2/test/test_031_51.png']
# processing (3555)-th image... ['datasets/apis2/test/test_031_56.png']
# processing (3560)-th image... ['datasets/apis2/test/test_031_61.png']
# processing (3565)-th image... ['datasets/apis2/test/test_031_66.png']
# processing (3570)-th image... ['datasets/apis2/test/test_031_71.png']
# processing (3575)-th image... ['datasets/apis2/test/test_031_76.png']
# processing (3580)-th image... ['datasets/apis2/test/test_031_81.png']
# processing (3585)-th image... ['datasets/apis2/test/test_031_86.png']
# processing (3590)-th image... ['datasets/apis2/test/test_031_91.png']
# processing (3595)-th image... ['datasets/apis2/test/test_031_96.png']
# processing (3600)-th image... ['datasets/apis2/test/test_032_101.png']
# processing (3605)-th image... ['datasets/apis2/test/test_032_106.png']
# processing (3610)-th image... ['datasets/apis2/test/test_032_111.png']
# processing (3615)-th image... ['datasets/apis2/test/test_032_116.png']
# processing (3620)-th image... ['datasets/apis2/test/test_032_121.png']
# processing (3625)-th image... ['datasets/apis2/test/test_032_126.png']
# processing (3630)-th image... ['datasets/apis2/test/test_032_131.png']
# processing (3635)-th image... ['datasets/apis2/test/test_032_17.png']
# processing (3640)-th image... ['datasets/apis2/test/test_032_22.png']
# processing (3645)-th image... ['datasets/apis2/test/test_032_27.png']
# processing (3650)-th image... ['datasets/apis2/test/test_032_32.png']
# processing (3655)-th image... ['datasets/apis2/test/test_032_37.png']
# processing (3660)-th image... ['datasets/apis2/test/test_032_42.png']
# processing (3665)-th image... ['datasets/apis2/test/test_032_47.png']
# processing (3670)-th image... ['datasets/apis2/test/test_032_52.png']
# processing (3675)-th image... ['datasets/apis2/test/test_032_57.png']
# processing (3680)-th image... ['datasets/apis2/test/test_032_62.png']
# processing (3685)-th image... ['datasets/apis2/test/test_032_67.png']
# processing (3690)-th image... ['datasets/apis2/test/test_032_72.png']
# processing (3695)-th image... ['datasets/apis2/test/test_032_77.png']
# processing (3700)-th image... ['datasets/apis2/test/test_032_82.png']
# processing (3705)-th image... ['datasets/apis2/test/test_032_87.png']
# processing (3710)-th image... ['datasets/apis2/test/test_032_92.png']
# processing (3715)-th image... ['datasets/apis2/test/test_032_97.png']
# processing (3720)-th image... ['datasets/apis2/test/test_033_102.png']
# processing (3725)-th image... ['datasets/apis2/test/test_033_107.png']
# processing (3730)-th image... ['datasets/apis2/test/test_033_112.png']
# processing (3735)-th image... ['datasets/apis2/test/test_033_117.png']
# processing (3740)-th image... ['datasets/apis2/test/test_033_122.png']
# processing (3745)-th image... ['datasets/apis2/test/test_033_127.png']
# processing (3750)-th image... ['datasets/apis2/test/test_033_132.png']
# processing (3755)-th image... ['datasets/apis2/test/test_033_137.png']
# processing (3760)-th image... ['datasets/apis2/test/test_033_142.png']
# processing (3765)-th image... ['datasets/apis2/test/test_033_33.png']
# processing (3770)-th image... ['datasets/apis2/test/test_033_38.png']
# processing (3775)-th image... ['datasets/apis2/test/test_033_43.png']
# processing (3780)-th image... ['datasets/apis2/test/test_033_48.png']
# processing (3785)-th image... ['datasets/apis2/test/test_033_53.png']
# processing (3790)-th image... ['datasets/apis2/test/test_033_58.png']
# processing (3795)-th image... ['datasets/apis2/test/test_033_63.png']
# processing (3800)-th image... ['datasets/apis2/test/test_033_68.png']
# processing (3805)-th image... ['datasets/apis2/test/test_033_73.png']
# processing (3810)-th image... ['datasets/apis2/test/test_033_78.png']
# processing (3815)-th image... ['datasets/apis2/test/test_033_83.png']
# processing (3820)-th image... ['datasets/apis2/test/test_033_88.png']
# processing (3825)-th image... ['datasets/apis2/test/test_033_93.png']
# processing (3830)-th image... ['datasets/apis2/test/test_033_98.png']
# processing (3835)-th image... ['datasets/apis2/test/test_034_103.png']
# processing (3840)-th image... ['datasets/apis2/test/test_034_108.png']
# processing (3845)-th image... ['datasets/apis2/test/test_034_113.png']
# processing (3850)-th image... ['datasets/apis2/test/test_034_118.png']
# processing (3855)-th image... ['datasets/apis2/test/test_034_123.png']
# processing (3860)-th image... ['datasets/apis2/test/test_034_128.png']
# processing (3865)-th image... ['datasets/apis2/test/test_034_133.png']
# processing (3870)-th image... ['datasets/apis2/test/test_034_138.png']
# processing (3875)-th image... ['datasets/apis2/test/test_034_28.png']
# processing (3880)-th image... ['datasets/apis2/test/test_034_33.png']
# processing (3885)-th image... ['datasets/apis2/test/test_034_38.png']
# processing (3890)-th image... ['datasets/apis2/test/test_034_43.png']
# processing (3895)-th image... ['datasets/apis2/test/test_034_48.png']
# processing (3900)-th image... ['datasets/apis2/test/test_034_53.png']
# processing (3905)-th image... ['datasets/apis2/test/test_034_58.png']
# processing (3910)-th image... ['datasets/apis2/test/test_034_63.png']
# processing (3915)-th image... ['datasets/apis2/test/test_034_68.png']
# processing (3920)-th image... ['datasets/apis2/test/test_034_73.png']
# processing (3925)-th image... ['datasets/apis2/test/test_034_78.png']
# processing (3930)-th image... ['datasets/apis2/test/test_034_83.png']
# processing (3935)-th image... ['datasets/apis2/test/test_034_88.png']
# processing (3940)-th image... ['datasets/apis2/test/test_034_93.png']
# processing (3945)-th image... ['datasets/apis2/test/test_034_98.png']
# processing (3950)-th image... ['datasets/apis2/test/test_035_103.png']
# processing (3955)-th image... ['datasets/apis2/test/test_035_108.png']
# processing (3960)-th image... ['datasets/apis2/test/test_035_113.png']
# processing (3965)-th image... ['datasets/apis2/test/test_035_118.png']
# processing (3970)-th image... ['datasets/apis2/test/test_035_123.png']
# processing (3975)-th image... ['datasets/apis2/test/test_035_128.png']
# processing (3980)-th image... ['datasets/apis2/test/test_035_133.png']
# processing (3985)-th image... ['datasets/apis2/test/test_035_37.png']
# processing (3990)-th image... ['datasets/apis2/test/test_035_42.png']
# processing (3995)-th image... ['datasets/apis2/test/test_035_47.png']
# processing (4000)-th image... ['datasets/apis2/test/test_035_52.png']
# processing (4005)-th image... ['datasets/apis2/test/test_035_57.png']
# processing (4010)-th image... ['datasets/apis2/test/test_035_62.png']
# processing (4015)-th image... ['datasets/apis2/test/test_035_67.png']
# processing (4020)-th image... ['datasets/apis2/test/test_035_72.png']
# processing (4025)-th image... ['datasets/apis2/test/test_035_77.png']
# processing (4030)-th image... ['datasets/apis2/test/test_035_82.png']
# processing (4035)-th image... ['datasets/apis2/test/test_035_87.png']
# processing (4040)-th image... ['datasets/apis2/test/test_035_92.png']
# processing (4045)-th image... ['datasets/apis2/test/test_035_97.png']
# processing (4050)-th image... ['datasets/apis2/test/test_036_102.png']
# processing (4055)-th image... ['datasets/apis2/test/test_036_107.png']
# processing (4060)-th image... ['datasets/apis2/test/test_036_112.png']
# processing (4065)-th image... ['datasets/apis2/test/test_036_117.png']
# processing (4070)-th image... ['datasets/apis2/test/test_036_122.png']
# processing (4075)-th image... ['datasets/apis2/test/test_036_127.png']
# processing (4080)-th image... ['datasets/apis2/test/test_036_132.png']
# processing (4085)-th image... ['datasets/apis2/test/test_036_137.png']
# processing (4090)-th image... ['datasets/apis2/test/test_036_29.png']
# processing (4095)-th image... ['datasets/apis2/test/test_036_34.png']
# processing (4100)-th image... ['datasets/apis2/test/test_036_39.png']
# processing (4105)-th image... ['datasets/apis2/test/test_036_44.png']
# processing (4110)-th image... ['datasets/apis2/test/test_036_49.png']
# processing (4115)-th image... ['datasets/apis2/test/test_036_54.png']
# processing (4120)-th image... ['datasets/apis2/test/test_036_59.png']
# processing (4125)-th image... ['datasets/apis2/test/test_036_64.png']
# processing (4130)-th image... ['datasets/apis2/test/test_036_69.png']
# processing (4135)-th image... ['datasets/apis2/test/test_036_74.png']
# processing (4140)-th image... ['datasets/apis2/test/test_036_79.png']
# processing (4145)-th image... ['datasets/apis2/test/test_036_84.png']
# processing (4150)-th image... ['datasets/apis2/test/test_036_89.png']
# processing (4155)-th image... ['datasets/apis2/test/test_036_94.png']
# processing (4160)-th image... ['datasets/apis2/test/test_036_99.png']
# processing (4165)-th image... ['datasets/apis2/test/test_037_104.png']
# processing (4170)-th image... ['datasets/apis2/test/test_037_109.png']
# processing (4175)-th image... ['datasets/apis2/test/test_037_114.png']
# processing (4180)-th image... ['datasets/apis2/test/test_037_119.png']
# processing (4185)-th image... ['datasets/apis2/test/test_037_124.png']
# processing (4190)-th image... ['datasets/apis2/test/test_037_23.png']
# processing (4195)-th image... ['datasets/apis2/test/test_037_28.png']
# processing (4200)-th image... ['datasets/apis2/test/test_037_33.png']
# processing (4205)-th image... ['datasets/apis2/test/test_037_38.png']
# processing (4210)-th image... ['datasets/apis2/test/test_037_43.png']
# processing (4215)-th image... ['datasets/apis2/test/test_037_48.png']
# processing (4220)-th image... ['datasets/apis2/test/test_037_53.png']
# processing (4225)-th image... ['datasets/apis2/test/test_037_58.png']
# processing (4230)-th image... ['datasets/apis2/test/test_037_63.png']
# processing (4235)-th image... ['datasets/apis2/test/test_037_68.png']
# processing (4240)-th image... ['datasets/apis2/test/test_037_73.png']
# processing (4245)-th image... ['datasets/apis2/test/test_037_78.png']
# processing (4250)-th image... ['datasets/apis2/test/test_037_83.png']
# processing (4255)-th image... ['datasets/apis2/test/test_037_88.png']
# processing (4260)-th image... ['datasets/apis2/test/test_037_93.png']
# processing (4265)-th image... ['datasets/apis2/test/test_037_98.png']

# %% [markdown]
# # Visualize

# %%
import matplotlib.pyplot as plt

img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/100_fake_B.png')
plt.imshow(img)

# %%
img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/100_real_A.png')
plt.imshow(img)

# %%
img = plt.imread('./results/facades_label2photo_pretrained/test_latest/images/100_real_B.png')
plt.imshow(img)

# %%
# !python embeddings.py --dataroot datasets/apis/ --direction AtoB --model pix2pix --name apis_pix2pix_NCCT_DWI --num_test 647 --no_dropout

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from skimage.transform import resize
import nibabel as nib
import numpy as np
import os

# %%
def window_image(image, window_center=60, window_width=120):
    img_min = window_center - window_width // 2
    img_max = window_center + window_width // 2
    window_image = image.copy()
    window_image[window_image < img_min] = img_min
    window_image[window_image > img_max] = img_max
    return window_image

# %%
def min_max_normalization(data: np.ndarray) -> np.ndarray:
    """Returns a min-max normalized data array. The values for the
    normalized array will lie between 0 and 1.

    Args:
        data (np.ndarray): array to be normalized

    Returns:
        np.ndarray: Normalized data
    """
    min = data.min()
    max = data.max()
    return (data - min) / (max - min)

# %%
#mypath = "/data/without_synthsr/train/"
mypath = "/data/synthsr/train/"
myoutputpath = "datasets/apis2/train/"
myoutputpath2 = "datasets/apis3/train/"
myoutputpath_mask = "datasets/apis2_mask/train/"

mylist = os.listdir(mypath)
mylist.sort()

k = 1
for fn in mylist:
    #if fn != "train_002":
    #    continue
    print(str(k), "of", len(mylist), end="\r")
    img1 = nib.load(os.path.join(mypath, fn, fn+"_ncct.nii.gz")).get_fdata()
    img1 = window_image(img1, 60, 120)
    img1 = min_max_normalization(img1)
    img2 = nib.load(os.path.join(mypath, fn, fn+"_adc.nii.gz")).get_fdata()
    img2 = min_max_normalization(img2)
    if os.path.isfile(os.path.join(mypath, fn, "masks", fn+"_r1_mask.nii.gz")):
        mask = nib.load(os.path.join(mypath, fn, "masks", fn+"_r1_mask.nii.gz")).get_fdata()
    else:
        mask = nib.load(os.path.join(mypath, fn, "masks", fn+"_r2_mask.nii.gz")).get_fdata()

    if img1.shape[0]>img1.shape[1]:
        zs = np.zeros((512,512,img1.shape[2]))
        img1 = resize(img1, (512,int(512/(img1.shape[0]/img1.shape[1]))))
        zs[:, ((img1.shape[0]-img1.shape[1])//2):((img1.shape[0]-img1.shape[1])//2)+img1.shape[1], :] = img1
        img1 = zs
        
        zs = np.zeros((512,512,img2.shape[2]))
        img2 = resize(img2, (512, int(512/(img2.shape[0]/img2.shape[1]))))
        zs[:, ((img2.shape[0]-img2.shape[1])//2):((img2.shape[0]-img2.shape[1])//2)+img2.shape[1], :] = img2
        img2 = zs
        
        zs = np.zeros((512,512,mask.shape[2]))
        mask = resize(mask, (512, int(512/(mask.shape[0]/mask.shape[1]))))
        zs[:, ((mask.shape[0]-mask.shape[1])//2):((mask.shape[0]-mask.shape[1])//2)+mask.shape[1], :] = mask
        mask = zs
    elif img1.shape[0]<img1.shape[1]:
        zs = np.zeros((512,512,img1.shape[2]))
        img1 = resize(img1, ((int(512/(img1.shape[1]/img1.shape[0]))), 512))
        zs[((img1.shape[1]-img1.shape[0])//2):((img1.shape[1]-img1.shape[0])//2)+img1.shape[0], :, :] = img1
        img1 = zs
        
        zs = np.zeros((512,512,img2.shape[2]))
        img2 = resize(img2, ((int(512/(img2.shape[1]/img2.shape[0]))), 512))
        zs[((img2.shape[1]-img2.shape[0])//2):((img2.shape[1]-img2.shape[0])//2)+img2.shape[0], :, :] = img2
        img2 = zs
        
        zs = np.zeros((512,512,mask.shape[2]))
        mask = resize(mask, ((int(512/(mask.shape[1]/mask.shape[0]))), 512))
        zs[((mask.shape[1]-mask.shape[0])//2):((mask.shape[1]-mask.shape[0])//2)+mask.shape[0], :, :] = mask
        mask = zs
    else:
        #equal w and h
        zs = np.zeros((512,512,img1.shape[2]))
        img1 = resize(img1, (512, 512))
        zs = img1
        img1 = zs
        
        zs = np.zeros((512,512,img2.shape[2]))
        img2 = resize(img2, (512, 512))
        zs = img2
        img2 = zs
        
        mask = resize(mask, (512, 512))
        #zs = np.zeros((512,512,mask.shape[2]))
        #mask = zs

    #print("mask", mask.shape)
    #mask = resize(mask, (512,411))
    #zs = np.zeros((512,512,mask.shape[2]))
    #zs[:, ((mask.shape[0]-mask.shape[1])//2):((mask.shape[0]-mask.shape[1])//2)+mask.shape[1], :] = mask
    #mask = zs
    #print("mask", mask.shape)
    for s in range(img1.shape[2]):
        if np.sum(np.where(img1[:,:,s]>0, 1, 0))>22000:
            #print(s, "...", np.sum(np.where(img1[:,:,s]>0, 1, 0)))
            img1_array = img1[:,:,s]
            img2_array = img2[:,:,s]
            mask_array = mask[:,:,s]
            myarray = np.hstack((img1_array,img2_array))
            myarray2 = np.hstack((img2_array,img1_array))
            #plt.imsave(os.path.join(myoutputpath, fn+"_"+str(s)+".png"), myarray, cmap="gray")
            #plt.imsave(os.path.join(myoutputpath2, fn+"_"+str(s)+".png"), myarray2, cmap="gray")
            plt.imsave(os.path.join(myoutputpath_mask, fn+"_"+str(s)+".png"), mask_array, cmap="gray")
        else:
            continue
    #break
    k += 1
print("")
print("DONE")

# %%
#mypath = "/data/without_synthsr/test/"
mypath = "/data/synthsr/test/"
myoutputpath = "datasets/apis2/test/"
myoutputpath2 = "datasets/apis3/test/"
myoutputpath_mask = "datasets/apis2_mask/test/"

mylist = os.listdir(mypath)
mylist.sort()

k = 1
for fn in mylist:
    #if fn != "train_002":
    #    continue
    print(str(k), "of", len(mylist), end="\r")
    img1 = nib.load(os.path.join(mypath, fn, fn+"_ncct.nii.gz")).get_fdata()
    img1 = window_image(img1, 60, 120)
    img1 = min_max_normalization(img1)
    img2 = nib.load(os.path.join(mypath, fn, fn+"_adc.nii.gz")).get_fdata()
    img2 = min_max_normalization(img2)
    if os.path.isfile(os.path.join(mypath, fn, "masks", fn+"_r1_mask.nii.gz")):
        mask = nib.load(os.path.join(mypath, fn, "masks", fn+"_r1_mask.nii.gz")).get_fdata()
    else:
        mask = nib.load(os.path.join(mypath, fn, "masks", fn+"_r2_mask.nii.gz")).get_fdata()

    if img1.shape[0]>img1.shape[1]:
        zs = np.zeros((512,512,img1.shape[2]))
        img1 = resize(img1, (512, int(512/(img1.shape[0]/img1.shape[1]))))
        zs[:, ((img1.shape[0]-img1.shape[1])//2):((img1.shape[0]-img1.shape[1])//2)+img1.shape[1], :] = img1
        img1 = zs
        
        zs = np.zeros((512,512,img2.shape[2]))
        img2 = resize(img2, (512, int(512/(img2.shape[0]/img2.shape[1]))))
        zs[:, ((img2.shape[0]-img2.shape[1])//2):((img2.shape[0]-img2.shape[1])//2)+img2.shape[1], :] = img2
        img2 = zs
        
        zs = np.zeros((512,512,mask.shape[2]))
        mask = resize(mask, (512, int(512/(mask.shape[0]/mask.shape[1]))))
        zs[:, ((mask.shape[0]-mask.shape[1])//2):((mask.shape[0]-mask.shape[1])//2)+mask.shape[1], :] = mask
        mask = zs
    elif img1.shape[0]<img1.shape[1]:
        zs = np.zeros((512,512,img1.shape[2]))
        img1 = resize(img1, ((int(512/(img1.shape[1]/img1.shape[0]))), 512))
        zs[((img1.shape[1]-img1.shape[0])//2):((img1.shape[1]-img1.shape[0])//2)+img1.shape[0], :, :] = img1
        img1 = zs
        
        zs = np.zeros((512,512,img2.shape[2]))
        img2 = resize(img2, ((int(512/(img2.shape[1]/img2.shape[0]))), 512))
        zs[((img2.shape[1]-img2.shape[0])//2):((img2.shape[1]-img2.shape[0])//2)+img2.shape[0], :, :] = img2
        img2 = zs
        
        zs = np.zeros((512,512,mask.shape[2]))
        mask = resize(mask, ((int(512/(mask.shape[1]/mask.shape[0]))), 512))
        zs[((mask.shape[1]-mask.shape[0])//2):((mask.shape[1]-mask.shape[0])//2)+mask.shape[0], :, :] = mask
        mask = zs
    else:
        #equal w and h
        zs = np.zeros((512,512,img1.shape[2]))
        img1 = resize(img1, (512, 512))
        zs = img1
        img1 = zs
        
        zs = np.zeros((512,512,img2.shape[2]))
        img2 = resize(img2, (512, 512))
        zs = img2
        img2 = zs
        
        mask = resize(mask, (512, 512))
        #zs = np.zeros((512,512,mask.shape[2]))
        #mask = zs

    #print("mask", mask.shape)
    #mask = resize(mask, (512,411))
    #zs = np.zeros((512,512,mask.shape[2]))
    #zs[:, ((mask.shape[0]-mask.shape[1])//2):((mask.shape[0]-mask.shape[1])//2)+mask.shape[1], :] = mask
    #mask = zs
    #print("mask", mask.shape)
    for s in range(img1.shape[2]):
        if np.sum(np.where(img1[:,:,s]>0, 1, 0))>22000:
            #print(s, "...", np.sum(np.where(img1[:,:,s]>0, 1, 0)))
            img1_array = img1[:,:,s]
            img2_array = img2[:,:,s]
            mask_array = mask[:,:,s]
            myarray = np.hstack((img1_array,img2_array))
            myarray2 = np.hstack((img2_array,img1_array))
            #plt.imsave(os.path.join(myoutputpath, fn+"_"+str(s)+".png"), myarray, cmap="gray")
            #plt.imsave(os.path.join(myoutputpath2, fn+"_"+str(s)+".png"), myarray2, cmap="gray")
            plt.imsave(os.path.join(myoutputpath_mask, fn+"_"+str(s)+".png"), mask_array, cmap="gray")
        else:
            continue
    #break
    k += 1
print("")
print("DONE")

# %%
def maskbox(fn):
    image = fn
    h_start = 0
    h_end = 0
    v_start = 0
    v_end = 0
    for kk,p in enumerate(np.sum(image, axis=0)):
        if(p!=0):
            h_start = kk
            print(kk)
            break
    for p in range(image.shape[0]-1,0,-1):
        if(np.sum(image, axis=0)[p]!=0):
            h_end = p
            print(p)
            break
    for kk,p in enumerate(np.sum(image, axis=1)):
        if(p!=0):
            v_start = kk
            print(kk)
            break
    for p in range(image.shape[0]-1,0,-1):
        if(np.sum(image, axis=1)[p]!=0):
            v_end = p
            print(p)
            break
    return h_start,h_end,v_start,v_end

# %%
img_ncct = mpimg.imread("datasets/apis2/train/train_026_44.png")[:,:512,0]
img_ncct = resize(img_ncct, (256,256))
img_adc = mpimg.imread("datasets/apis2/train/train_026_44.png")[:,512:,0]
img_adc = resize(img_adc, (256,256))
img_mask = mpimg.imread("datasets/apis2_mask/train/train_026_44.png")[...,0]
img_mask = resize(img_mask, (256,256))
h_start,h_end,v_start,v_end = maskbox(img_mask)

plt.subplot(1,2,1)
plt.imshow(img_adc, cmap="gray")
plt.imshow(img_mask, alpha=0.5)
plt.axhline(y=v_start, color="white", lw=0.8, linestyle="--")
plt.axhline(y=v_end, color="white", lw=0.8, linestyle="--")
plt.axvline(x=h_start, color="white", lw=0.8, linestyle="--")
plt.axvline(x=h_end, color="white", lw=0.8, linestyle="--")

plt.subplot(1,2,2)
plt.imshow(img_adc[v_start:v_end, h_start:h_end], cmap="gray")
plt.imshow(img_mask[v_start:v_end, h_start:h_end], alpha=0.5)

plt.show()
